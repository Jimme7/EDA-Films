# %%
import pandas as pd

# %%
films = pd.read_csv('../Data/films.csv', index_col= 0)
genre_films = pd.read_csv('../Data/films_genre.csv', index_col= 0)
series = pd.read_csv('../Data/series.csv', index_col= 0)
genre_series = pd.read_csv('../Data/series_genre.csv', index_col= 0)

# %%
films.head()
# Out:
#    film_id              title original_language           genre_ids  \
# 0   565770        Blue Beetle                en       [28, 878, 12]
# 1   762430        Retribution                en  [28, 9648, 53, 80]
# 2   615656  Meg 2: The Trench                en       [28, 878, 27]
# 3   385687             Fast X                en        [28, 80, 53]
# 4  1008042         Talk to Me                en            [27, 53]
#
#   release_date  popularity  vote_average  vote_count
# 0   2023-08-16    3180.600           7.2         910
# 1   2023-08-23    1730.839           6.8         230
# 2   2023-08-02    1363.273           7.0        1959
# 3   2023-05-17    1264.755           7.3        3852
# 4   2023-07-26    1207.188           7.2         876

# %%
films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1980 entries, 0 to 1979
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   film_id            1980 non-null   int64
#  1   title              1980 non-null   object
#  2   original_language  1980 non-null   object
#  3   genre_ids          1980 non-null   object
#  4   release_date       1980 non-null   object
#  5   popularity         1980 non-null   float64
#  6   vote_average       1980 non-null   float64
#  7   vote_count         1980 non-null   int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 139.2+ KB

# %%
genre_films.head()
# Out:
#    id      genre
# 0  12  Adventure
# 1  14    Fantasy
# 2  16  Animation
# 3  18      Drama
# 4  27     Horror

# %%
genre_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 0 to 18
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      19 non-null     int64
#  1   genre   19 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 456.0+ bytes

# %%
series.head()
# Out:
#    serie_id                 name            genre_id origin_country  \
# 0     94722           Tagesschau             [10763]         ['DE']
# 1    215103  Teri Meri Doriyaann         [18, 10751]         ['IN']
# 2    215803        Batang Quiapo     [10759, 35, 18]         ['PH']
# 3    215315      Rabb Se Hai Dua                [18]         ['IN']
# 4    215902        Katha Ankahee  [18, 10751, 10766]         ['IN']
#
#    popularity  vote_average  vote_count
# 0    3183.847           7.5         145
# 1    3103.841           7.2         110
# 2    3072.452           7.0          99
# 3    3061.452           6.7          90
# 4    2986.341           7.5         106

# %%
series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1980 entries, 0 to 1979
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   serie_id        1980 non-null   int64
#  1   name            1980 non-null   object
#  2   genre_id        1980 non-null   object
#  3   origin_country  1980 non-null   object
#  4   popularity      1980 non-null   float64
#  5   vote_average    1980 non-null   float64
#  6   vote_count      1980 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 123.8+ KB

# %%
genre_series.head()
# Out:
#    id      genre
# 0  16  Animation
# 1  18      Drama
# 2  35     Comedy
# 3  37    Western
# 4  80      Crime

# %%
genre_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      16 non-null     int64
#  1   genre   16 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 384.0+ bytes

# %% [markdown]
# ----

# %% [markdown]
# Para nuestro análisis el la columna de id de género, tanto en las películas como en las series, no nos va a ser de mucha utilidad. Como hemos obtenido a través de la API a qué género corresponde cada ID, lo primero que haremos será añadirlos a los df principales a través de un merge.

# %%
#La columna género_id de cada DF es una lista, vamos a quedarnos con el primer género como si fuese el género principal

films ['genre_ids'] = films['genre_ids'].str.replace('[','').str.replace(']', '').str.split(',').str[0]
# Out:
# C:\Users\jimea\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
films
# Out:
#       film_id                                 title original_language  \
# 0      565770                           Blue Beetle                en
# 1      762430                           Retribution                en
# 2      615656                     Meg 2: The Trench                en
# 3      385687                                Fast X                en
# 4     1008042                            Talk to Me                en
# ...       ...                                   ...               ...
# 1975   340382  Attack on Titan II: End of the World                ja
# 1976    51739          The Secret World of Arrietty                ja
# 1977   630940        Jokyoshi Nikki 2 Abakareta Sei                ja
# 1978     1954                  The Butterfly Effect                en
# 1979    23202                        Trick 'r Treat                en
#
#      genre_ids release_date  popularity  vote_average  vote_count
# 0           28   2023-08-16    3180.600           7.2         910
# 1           28   2023-08-23    1730.839           6.8         230
# 2           28   2023-08-02    1363.273           7.0        1959
# 3           28   2023-05-17    1264.755           7.3        3852
# 4           27   2023-07-26    1207.188           7.2         876
# ...        ...          ...         ...           ...         ...
# 1975        27   2015-09-01      34.586           6.1         290
# 1976        14   2010-07-16      34.580           7.6        2561
# 1977             1996-06-13      34.577           9.3           6
# 1978       878   2004-01-17      34.573           7.6        6889
# 1979        27   2007-10-26      34.572           7.0        1666
#
# [1980 rows x 8 columns]

# %%
#Como podemos comprobar, al hacer esto hay filas que quedan con espacios vacíos
mask = films['genre_ids'] == ''
len(films[mask])
# Out:
# 10

# %%
#Como no son muchas filas, vamos a borrarlas
films.drop(films[mask].index, inplace= True)
films.reset_index(inplace=True, drop= True)

# %%
films
# Out:
#       film_id                                 title original_language  \
# 0      565770                           Blue Beetle                en
# 1      762430                           Retribution                en
# 2      615656                     Meg 2: The Trench                en
# 3      385687                                Fast X                en
# 4     1008042                            Talk to Me                en
# ...       ...                                   ...               ...
# 1965   589761                      Chernobyl: Abyss                ru
# 1966   340382  Attack on Titan II: End of the World                ja
# 1967    51739          The Secret World of Arrietty                ja
# 1968     1954                  The Butterfly Effect                en
# 1969    23202                        Trick 'r Treat                en
#
#      genre_ids release_date  popularity  vote_average  vote_count
# 0           28   2023-08-16    3180.600           7.2         910
# 1           28   2023-08-23    1730.839           6.8         230
# 2           28   2023-08-02    1363.273           7.0        1959
# 3           28   2023-05-17    1264.755           7.3        3852
# 4           27   2023-07-26    1207.188           7.2         876
# ...        ...          ...         ...           ...         ...
# 1965        18   2021-04-15      34.611           6.2         445
# 1966        27   2015-09-01      34.586           6.1         290
# 1967        14   2010-07-16      34.580           7.6        2561
# 1968       878   2004-01-17      34.573           7.6        6889
# 1969        27   2007-10-26      34.572           7.0        1666
#
# [1970 rows x 8 columns]
