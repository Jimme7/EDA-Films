# %% [markdown]
# ## EXTRAEMOS LOS DATOS DE LA API DE TMBD

# %%
import requests
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ### `Extraemos los datos acerca de las series:`

# %%
#Primero un ejemplo del acceso a una página para visualizar que tipo de datos tenemos
url = "https://api.themoviedb.org/3/discover/tv?include_adult=false&include_null_first_air_dates=false&language=en-US&page=1&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1YTRjNWU0MGNlZWM2NTMwZjBhZmNkZjVmNjMwOGYyOSIsInN1YiI6IjYzZjYwYzY5OGMyMmMwMDBjZTNlNjMxMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.4k-HhqE--f_0tsWbbX2iaMeFAgyAOVSPynKbQ7rntJM"
}

r = requests.get(url, headers=headers)
r.json()
# Out:
# {'page': 1,
#  'results': [{'backdrop_path': '/jWXrQstj7p3Wl5MfYWY6IHqRpDb.jpg',
#    'first_air_date': '1952-12-26',
#    'genre_ids': [10763],
#    'id': 94722,
#    'name': 'Tagesschau',
#    'origin_country': ['DE'],
#    'original_language': 'de',
#    'original_name': 'Tagesschau',
#    'overview': 'German daily news program, the oldest still existing program on German television.',
#    'popularity': 3358.953,
#    'poster_path': '/7dFZJ2ZJJdcmkp05B9NWlqTJ5tq.jpg',
#    'vote_average': 7.5,
#    'vote_count': 147},
#   {'backdrop_path': '/1Xm0WqoT0DjZm5JdG2V6YFabrOz.jpg',
#    'first_air_date': '2023-02-13',
#    'genre_ids': [10759, 35, 18],
#    'id': 215803,
#    'name': 'Batang Quiapo',
#    'origin_country': ['PH'],
#    'original_language': 'tl',
#    'original_name': 'Quiapo Kid',
# ...

# %%
r.json().keys()
# Out:
# dict_keys(['page', 'results', 'total_pages', 'total_results'])

# %%
r.json()['results']
#solo nos interesa acceder a los resultados
# Out:
# [{'backdrop_path': '/jWXrQstj7p3Wl5MfYWY6IHqRpDb.jpg',
#   'first_air_date': '1952-12-26',
#   'genre_ids': [10763],
#   'id': 94722,
#   'name': 'Tagesschau',
#   'origin_country': ['DE'],
#   'original_language': 'de',
#   'original_name': 'Tagesschau',
#   'overview': 'German daily news program, the oldest still existing program on German television.',
#   'popularity': 3186.016,
#   'poster_path': '/7dFZJ2ZJJdcmkp05B9NWlqTJ5tq.jpg',
#   'vote_average': 7.5,
#   'vote_count': 145},
#  {'backdrop_path': '/3n2TjKw3HrwDqgVgcynvantOfS3.jpg',
#   'first_air_date': '2023-01-04',
#   'genre_ids': [18, 10751],
#   'id': 215103,
#   'name': 'Teri Meri Doriyaann',
#   'origin_country': ['IN'],
#   'original_language': 'hi',
#   'original_name': 'तेरी मेरी डोरियाँ',
#   'overview': 'It’s hate at first sight for Sahiba and Angad! But destined to be together, their lives get intertwined by a marriage alliance, and a love-hate story ensues.',
#   'popularity': 3135.635,
# ...

# %%
len(r.json()['results'])
#Con esto vemos cuantos resultados hay por página
# Out:
# 20

# %%
r.json()['results'][0] #el primer resultado
# Out:
# {'backdrop_path': '/jWXrQstj7p3Wl5MfYWY6IHqRpDb.jpg',
#  'first_air_date': '1952-12-26',
#  'genre_ids': [10763],
#  'id': 94722,
#  'name': 'Tagesschau',
#  'origin_country': ['DE'],
#  'original_language': 'de',
#  'original_name': 'Tagesschau',
#  'overview': 'German daily news program, the oldest still existing program on German television.',
#  'popularity': 3186.016,
#  'poster_path': '/7dFZJ2ZJJdcmkp05B9NWlqTJ5tq.jpg',
#  'vote_average': 7.5,
#  'vote_count': 145}

# %%
r.json()['results'][0]['name']
# Out:
# 'Tagesschau'

# %%
#Ahora vamos a crear un bucle while para obtener la información de las 200 primeras páginas
i = 1
serie_id = []
name = []
genre_id =[]
origin_country = []
original_language =[]
popularity = []
vote_average = []
vote_count = []

while i < 200:
  url = "https://api.themoviedb.org/3/discover/tv?include_adult=false&include_null_first_air_dates=false&language=en-US&page={}&sort_by=popularity.desc".format(i)
  headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1YTRjNWU0MGNlZWM2NTMwZjBhZmNkZjVmNjMwOGYyOSIsInN1YiI6IjYzZjYwYzY5OGMyMmMwMDBjZTNlNjMxMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.4k-HhqE--f_0tsWbbX2iaMeFAgyAOVSPynKbQ7rntJM"
    }
  response = requests.get(url, headers=headers)
  j = response.json()
  
  for z in range(20):
    serie_id.append(j['results'][z]['id'])
    name.append(j['results'][z]['name'])
    genre_id.append(j['results'][z]['genre_ids'])
    origin_country.append(j['results'][z]['origin_country'])
    popularity.append(j['results'][z]['popularity'])
    vote_average.append(j['results'][z]['vote_average'])
    vote_count.append(j['results'][z]['vote_count'])
  
  i += 1

# %%
#creamos nuestro DF de series con los datos obtenidos
data = {
    'serie_id': serie_id,
    'name': name,
    'genre_id': genre_id,
    'origin_country': origin_country,
    'popularity': popularity,
    'vote_average': vote_average,
    'vote_count': vote_count
}

series = pd.DataFrame(data)
series
# Out:
#       serie_id                  name            genre_id origin_country  \
# 0        94722            Tagesschau             [10763]           [DE]
# 1       215103   Teri Meri Doriyaann         [18, 10751]           [IN]
# 2       215803         Batang Quiapo     [10759, 35, 18]           [PH]
# 3       215315       Rabb Se Hai Dua                [18]           [IN]
# 4       215902         Katha Ankahee  [18, 10751, 10766]           [IN]
# ...        ...                   ...                 ...            ...
# 3975    233287        House Husbands                [35]           [US]
# 3976    100414             Suspicion            [18, 80]           [GB]
# 3977     94167  The Legend of El Cid  [10759, 18, 10768]           [ES]
# 3978     15768             The Guild                [35]           [US]
# 3979     44777            Starzinger  [10759, 16, 10765]           [JP]
#
#       popularity  vote_average  vote_count
# 0       3186.016           7.5         145
# ...

# %%
# Y guardamos el df obtenido para posteriormente trabajar con el
series.to_csv("../Data/series.csv")

# %% [markdown]
# Sacamos información sobre los géneros

# %%
#Llamamos a la API para obtener una tabla de qué género corresponde con cada ID

url = "https://api.themoviedb.org/3/genre/tv/list?language=en"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1YTRjNWU0MGNlZWM2NTMwZjBhZmNkZjVmNjMwOGYyOSIsInN1YiI6IjYzZjYwYzY5OGMyMmMwMDBjZTNlNjMxMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.4k-HhqE--f_0tsWbbX2iaMeFAgyAOVSPynKbQ7rntJM"
}

response = requests.get(url, headers=headers)

j= response.json()
j
# Out:
# {'genres': [{'id': 10759, 'name': 'Action & Adventure'},
#   {'id': 16, 'name': 'Animation'},
#   {'id': 35, 'name': 'Comedy'},
#   {'id': 80, 'name': 'Crime'},
#   {'id': 99, 'name': 'Documentary'},
#   {'id': 18, 'name': 'Drama'},
#   {'id': 10751, 'name': 'Family'},
#   {'id': 10762, 'name': 'Kids'},
#   {'id': 9648, 'name': 'Mystery'},
#   {'id': 10763, 'name': 'News'},
#   {'id': 10764, 'name': 'Reality'},
#   {'id': 10765, 'name': 'Sci-Fi & Fantasy'},
#   {'id': 10766, 'name': 'Soap'},
#   {'id': 10767, 'name': 'Talk'},
#   {'id': 10768, 'name': 'War & Politics'},
#   {'id': 37, 'name': 'Western'}]}

# %%
j['genres'][0]
# Out:
# {'id': 10759, 'name': 'Action & Adventure'}

# %%
id = []
genre = []

for i in range(len(j['genres'])):
    id.append(j['genres'][i]['id'])
    genre.append(j['genres'][i]['name'])

# %%
#Creamos el df con los géneros

data = {'id': id, 'genre': genre}

series_genre_df = pd.DataFrame(data).sort_values(by= 'id', ascending= True)
series_genre_df.reset_index(inplace=True, drop= True)
series_genre_df
# Out:
#        id               genre
# 0      16           Animation
# 1      18               Drama
# 2      35              Comedy
# 3      37             Western
# 4      80               Crime
# 5      99         Documentary
# 6    9648             Mystery
# 7   10751              Family
# 8   10759  Action & Adventure
# 9   10762                Kids
# 10  10763                News
# 11  10764             Reality
# 12  10765    Sci-Fi & Fantasy
# 13  10766                Soap
# 14  10767                Talk
# 15  10768      War & Politics

# %%
# Y lo guardamos como otro csv para posteriormente trabajar con él

series_genre_df.to_csv("../Data/series_genre.csv")

# %% [markdown]
# Por último, vamos a extraer información de la fecha de lanzamiento de cada serie, a través de otra URL de la API ya que de la general no podemos obtener esta información.

# %%
url = "https://api.themoviedb.org/3/tv/543?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1YTRjNWU0MGNlZWM2NTMwZjBhZmNkZjVmNjMwOGYyOSIsInN1YiI6IjYzZjYwYzY5OGMyMmMwMDBjZTNlNjMxMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.4k-HhqE--f_0tsWbbX2iaMeFAgyAOVSPynKbQ7rntJM"
}

response = requests.get(url, headers=headers)

print(response.text)

# %% [markdown]
# --------

# %% [markdown]
# ### `Extraemos los datos acerca de las películas:`

# %%
url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page={}&sort_by=popularity.desc".format(i)

# %%
i = 1
film_id = []
title = []
genre_id =[]
original_language =[]
release_date = []
popularity = []
vote_average = []
vote_count = []

while i < 200:

    url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page={}&sort_by=popularity.desc".format(i)
    headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1YTRjNWU0MGNlZWM2NTMwZjBhZmNkZjVmNjMwOGYyOSIsInN1YiI6IjYzZjYwYzY5OGMyMmMwMDBjZTNlNjMxMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.4k-HhqE--f_0tsWbbX2iaMeFAgyAOVSPynKbQ7rntJM"
    }

    response = requests.get(url, headers=headers)
    j = response.json()

    for z in range(20):
        try:
            release_date.append(j['results'][z]['release_date'])
        except KeyError:
            release_date.append(None)

        film_id.append(j['results'][z]['id'])
        title.append(j['results'][z]['title'])
        original_language.append(j['results'][z]['original_language'])
        genre_id.append(j['results'][z]['genre_ids'])
        popularity.append(j['results'][z]['popularity'])
        vote_average.append(j['results'][z]['vote_average'])
        vote_count.append(j['results'][z]['vote_count'])
    

    i += 1

# %%
data = {
    'film_id': film_id,
    'title': title,
    'original_language': original_language,
    'genre_ids': genre_id,
    'release_date': release_date,
    'popularity': popularity,
    'vote_average': vote_average,
    'vote_count': vote_count
}

films = pd.DataFrame(data)
films
# Out:
#       film_id                                      title original_language  \
# 0      565770                                Blue Beetle                en
# 1      762430                                Retribution                en
# 2      615656                          Meg 2: The Trench                en
# 3      385687                                     Fast X                en
# 4     1008042                                 Talk to Me                en
# ...       ...                                        ...               ...
# 3975     9493                                      Twins                en
# 3976   323372                   The Corpse of Anna Fritz                es
# 3977   221732  Rurouni Kenshin Part III: The Legend Ends                ja
# 3978     9087                     The American President                en
# 3979   777245                              Women Talking                en
#
# ...

# %%
#Guardamos nuestro df en un csv para posteriormente trabajar con él

films.to_csv('../Data/films.csv')

# %% [markdown]
# Sacamos también información sobre los géneros:

# %%
#Llamamos a la API para obtener una tabla de qué género corresponde con cada ID

url = "https://api.themoviedb.org/3/genre/movie/list?language=en"


headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1YTRjNWU0MGNlZWM2NTMwZjBhZmNkZjVmNjMwOGYyOSIsInN1YiI6IjYzZjYwYzY5OGMyMmMwMDBjZTNlNjMxMCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.4k-HhqE--f_0tsWbbX2iaMeFAgyAOVSPynKbQ7rntJM"
}

response = requests.get(url, headers=headers)

j= response.json()
j
# Out:
# {'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'},
#   {'id': 16, 'name': 'Animation'},
#   {'id': 35, 'name': 'Comedy'},
#   {'id': 80, 'name': 'Crime'},
#   {'id': 99, 'name': 'Documentary'},
#   {'id': 18, 'name': 'Drama'},
#   {'id': 10751, 'name': 'Family'},
#   {'id': 14, 'name': 'Fantasy'},
#   {'id': 36, 'name': 'History'},
#   {'id': 27, 'name': 'Horror'},
#   {'id': 10402, 'name': 'Music'},
#   {'id': 9648, 'name': 'Mystery'},
#   {'id': 10749, 'name': 'Romance'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 10770, 'name': 'TV Movie'},
#   {'id': 53, 'name': 'Thriller'},
#   {'id': 10752, 'name': 'War'},
#   {'id': 37, 'name': 'Western'}]}

# %%
j['genres'][0]
# Out:
# {'id': 28, 'name': 'Action'}

# %%
id = []
genre = []

for i in range(len(j['genres'])):
    id.append(j['genres'][i]['id'])
    genre.append(j['genres'][i]['name'])

# %%
#Creamos el df con los géneros

data = {'id': id, 'genre': genre}

genre_films_df = pd.DataFrame(data).sort_values(by= 'id', ascending= True)
genre_films_df.reset_index(inplace=True, drop= True)
genre_films_df
# Out:
#        id            genre
# 0      12        Adventure
# 1      14          Fantasy
# 2      16        Animation
# 3      18            Drama
# 4      27           Horror
# 5      28           Action
# 6      35           Comedy
# 7      36          History
# 8      37          Western
# 9      53         Thriller
# 10     80            Crime
# 11     99      Documentary
# 12    878  Science Fiction
# 13   9648          Mystery
# 14  10402            Music
# 15  10749          Romance
# 16  10751           Family
# 17  10752              War
# 18  10770         TV Movie

# %%
# Y lo guardamos

genre_films_df.to_csv('../Data/films_genre.csv')
